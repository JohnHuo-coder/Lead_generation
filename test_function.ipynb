# %%
from web_scraper import scrape_hotel_website_summary

# %%
result = scrape_hotel_website_summary("https://www.theparknine.com/suvarnabhumi/")
print(result["high_level_summary"])
# Out:
# Analyzed 12 page(s). Hotel style is likely luxury. Found 5 likely recent event mention(s). Likely target segments: families, luxury leisure travelers, business travelers.

# %%
events = result["recent_events"]
for i in events:
    print(i["event_summary"], "\n")
# Out:
# The 114 spacious rooms instill a mood of freedom for both work and pleasure, while the distinctly elegant lobby lounge offers a selection of innovative beverages, cocktails and snacks amidst the stunning view of a 130-year-old canal.
#
# We offer a range of outstanding accommodations and facilities, including our spacious tropical garden surrounding a beautiful marble-lined swimming pool.
#
# For guests that want to maintain their fitness while traveling, we offer a spacious and air-conditioned, fully-equipped fitness room.
#
# Our Dining Experiences The Park Nine Suvarnabhumi Hotel located close to Suvarnabhumi Airport in Bangkok also offers a choice of two dining experiences for our guests.
#
# Eat, Drink Love Suvarnabhumi is our all-day restaurant that offers a 'global sensation' of flavors.

# %%
combined_text = result["full_content"]
lst = combined_text.split(".")
for i in lst:
    print(i)
# Out:
# The Park Nine Suvarnabhumi | Deluxe Room Deluxe Room Home Accommodations Deluxe Room More Image Room size : 30 SQ
# M
#  Our DELUXE room type (30 Sq
# m
# ) decorated with warmest designed to unwind your disorderly day
#  The room offer Smart IP TV 43" with satellite channels Air Conditioning Bathroom amenities Bathrobe, slipper, hair dryer and flashlight Hot & Cold Shower Complimentary Bottled water Coffee and tea maker facilities Mini bar Individual control air - condition Wi- Fi & Lan internet Smoke & Heat detector Electronic Keycard Desk & Lamp
#
# The Park Nine Suvarnabhumi | Superior Room Superior Room Home Accommodations Superior Room More Image Room size : 28 SQ
# M
#  Our SUPERIOR room type (28 Sq
# m
# ) have been designed to accommodate your comfortable living stay experience
#  The room offer Smart IP TV 43" with satellite channels Air Conditioning Bathroom amenities (Daily stay only) Bathrobe, slipper, hair dryer and flashlight Hot & Cold Shower Complimentary Bottled water Coffee and tea maker facilities Mini bar Individual control air - condition Wi- Fi & Lan internet Smoke & Heat detector Electronic Keycard Desk & Lamp
#
# The Park Nine Suvarnabhumi | 2 Bedroom Suite Room 2 Bedroom Suite Room Home Accommodations 2 Bedroom Suite Room More Image Room size : 90 SQ
# M
#  2 BEDROOM SUITE (90 Sq
# m
# ) are extensive for your relatives and friends, fulled furnished with the spacious living area with fully equipped dining, cooking area table and kitchenware
#  The room offer Smart IP TV 52" with satellite channels (Living room) Smart IP TV 43" with satellite channels (Master Bedroom) Smart IP TV 32" with satellite channels (Master Bedroom) Personal deposit safe box Iron & iron board Umbrella Daybed Walk - in closet Mini bar Coffee & Tea maker (Daily stay only) Fully equipped kitchenette with refrigerator, microwave oven,kettle,china ware, glassware, crockery and cutlery Bathroom amenities (Daily stay only) Separate shower and bathtub Washer & dryer machine Separate individual air condition Wi-Fi Internet (optional LAN system available) Smoke & Heat detector Clothesline Private balcony with table and chair
#
# Hotel near suvarnabhumi airport with suite rooms Book a Hotel Near Suvarnabhumi Airport with Suite Rooms Home Accommodation Room and Suite Décor and Amenities Our Styles of Rooms and Suites Choice of Rooms to Suit Your Needs The main goal of travelers is to find modern, spacious accommodations wherever they happen to in the world
#  If you’re a business traveler, this becomes even more important
#  If you’re traveling with your family, you’ll also appreciate the children’s pool where the younger members of the family can enjoy splashing in the refreshing, shallow waters
#  For guests that want to maintain their fitness while traveling, we offer a spacious and air-conditioned, fully-equipped fitness room
#  The fitness room contains state-of-the-art cardio and aerobic equipment which they can use to stay in shape
#  There is a complete line-up of weight training equipment as well they can use to increase and maintain their strength while traveling
#  And what would a hotel close to Suvarnabhumi Airport in Thailand be without a free shuttle service? Our regularly scheduled shuttle service runs every two hours throughout the day
#  If you need to catch a flight during odd hours, our hotel staff will be happy to arrange transport when available
#  Our Dining Experiences The Park Nine Suvarnabhumi Hotel located close to Suvarnabhumi Airport in Bangkok also offers a choice of two dining experiences for our guests
#  Eat, Drink Love Suvarnabhumi is our all-day restaurant that offers a 'global sensation' of flavors
#  The chefs of EDL have created a signature menu of a hybrid culture where the tastes of Thailand are combined with modern preparation methods to offer our guests a delicious introduction to Thai cuisine in a relaxed and casual atmosphere
#  Cuppers is our café for people who appreciate a rich cup of coffee and a tantalizing display of fresh pastries and desserts
#  Our pastries are made from scratch every day of the week
#  It’s the perfect place to start your day or to hold a casual business meeting
#  The Park Nine Suvarnabhumi Hotel close to Suvarnabhumi Airport has everything the traveler for business or pleasure would want in location, facilities and dining experiences
#  Accommodation The main goal of travelers is to find modern, spacious
#
#
#  Discover Eat Drink Love SUVARNABHUMI The hotel all day dining restaurant offers a “Glocal
#
#
#  Discover CUPPERS Our café is a unique blend of tradition and bold innovation
#
#
#  Discover

# %%
result = scrape_hotel_website_summary("http://www.arantaairporthotel.com/")
print(result)
# Out:
# {'website_url': 'http://www.arantaairporthotel.com/', 'status': 'ok', 'pages_scanned': 12, 'recent_events': [{'source_url': 'http://www.arantaairporthotel.com/', 'date_hint': '', 'event_summary': 'The hotel offers an airport shuttle service that takes no more than 10 minutes to travel.'}, {'source_url': 'https://www.arantaairporthotel.com/about-us/', 'date_hint': '', 'event_summary': 'The hotel offers an airport shuttle service within a 10-minute drive.'}, {'source_url': 'https://www.arantaairporthotel.com/about-us/', 'date_hint': '', 'event_summary': 'Also, two saltwater swimming pools, elevators, conference room and a car park.'}, {'source_url': 'https://www.arantaairporthotel.com/about-us/', 'date_hint': '', 'event_summary': 'Service Airport transfer service Breakfast 2 outdoor saltwater swimming pools Elevator Wifi Parking place Conference room And others ABOUT US Aranta Airport Hotel is situated on the canal of Prawet Burirom where guests can enjoy the view of the river and the t'}, {'source_url': 'https://www.arantaairporthotel.com/about-us/', 'date_hint': '', 'event_summary': 'NEARBY The Paseo, Robinson, and the newly built Little walk shopping mall is a 10-minute walk from the hotel which offers many local street food, restaurants, shops and banks.'}], 'hotel_style': {'label': 'luxury', 'confidence': 0.61, 'evidence_keywords': ['spa', 'suite'], 'score': {'luxury_hits': 2, 'economy_hits': 0}}, 'target_customer_segments': [{'segment': 'business travelers', 'confidence': 0.65, 'evidence_keywords': ['conference', 'airport shuttle']}, {'segment': 'luxury leisure travelers', 'confidence': 0.65, 'evidence_keywords': ['spa', 'private']}, {'segment': 'families', 'confidence': 0.5, 'evidence_keywords': ['family']}], 'high_level_summary': 'Analyzed 12 page(s). Hotel style is likely luxury. Found 5 likely recent event mention(s). Likely target segments: business travelers, luxury leisure travelers, families.'}

# %%
events = result["recent_events"]
for i in events:
    print(i["event_summary"], "\n")
# Out:
# The hotel offers an airport shuttle service that takes no more than 10 minutes to travel.
#
# The hotel offers an airport shuttle service within a 10-minute drive.
#
# Also, two saltwater swimming pools, elevators, conference room and a car park.
#
# Service Airport transfer service Breakfast 2 outdoor saltwater swimming pools Elevator Wifi Parking place Conference room And others ABOUT US Aranta Airport Hotel is situated on the canal of Prawet Burirom where guests can enjoy the view of the river and the t
#
# NEARBY The Paseo, Robinson, and the newly built Little walk shopping mall is a 10-minute walk from the hotel which offers many local street food, restaurants, shops and banks.

# %%
from email_composer import compose_email
import json

with open("apify_results.json", "r") as f:
    leads = json.load(f)
result = compose_email(
    leads,
    collaboration_intent = "Host a MedSpa & Wellness event for the guest in the hotel", 
    sender_name = "John Huo",
    max_pages = 15,
)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from email_composer import compose_email
#       2 import json
#       3
#       4 with open("apify_results.json", "r") as f:
#
# File d:\B2B_lead_gen\email_composer.py:20
#      16 from web_scraper import MAX_PAGES, scrape_hotel_website_summary
#      18 load_dotenv()
# ---> 20 llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.4)
#      22 # Default ask — override with env OUTREACH_INTENT or pass collaboration_intent to compose_email.
#      23 DEFAULT_COLLABORATION_INTENT = (
#      24     "Host a MedSpa & Wellness event for the guest in the hotel"
#      25 )
#
# File d:\B2B_lead_gen\.venv\Lib\site-packages\langchain_core\load\serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File d:\B2B_lead_gen\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1253, in BaseChatOpenAI.validate_environment(self)
#    1239         self.http_async_client = _build_proxied_async_httpx_client(
#    1240             proxy=self.openai_proxy,
#    1241             verify=global_ssl_context,
#    1242             socket_options=resolved_socket_options,
#    1243         )
#    1244     async_specific = {
#    1245         "http_client": self.http_async_client
#    1246         or _get_default_async_httpx_client(
#    (...)   1251         "api_key": async_api_key_value,
#    1252     }
# -> 1253     self.root_async_client = openai.AsyncOpenAI(
#    1254         **client_params,
#    1255         **async_specific,  # type: ignore[arg-type]
#    1256     )
#    1257     self.async_client = self.root_async_client.chat.completions
#    1258 return self
#
# File d:\B2B_lead_gen\.venv\Lib\site-packages\openai\_client.py:700, in AsyncOpenAI.__init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#     691 self.admin_api_key = admin_api_key
#     693 if (
#     694     _enforce_credentials
#     695     and not self.api_key
#    (...)    698     and self.admin_api_key is None
#     699 ):
# --> 700     raise OpenAIError(
#     701         "Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable."
#     702     )
#     704 if organization is None:
#     705     organization = os.environ.get("OPENAI_ORG_ID")
#
# OpenAIError: Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.
